# %%
import numpy as np
import pandas as pd
PGA_TechData = pd.read_csv('../data/PGATOUR_data2.csv')
PGA_GenData = pd.read_csv('../data/pgaTourData.csv')

# %%
PGA_GenData
# Out:
#              Player Name  Rounds  Fairway Percentage  Year  Avg Distance  \
# 0         Henrik Stenson    60.0               75.19  2018         291.5
# 1            Ryan Armour   109.0               73.58  2018         283.5
# 2            Chez Reavie    93.0               72.24  2018         286.5
# 3             Ryan Moore    78.0               71.94  2018         289.2
# 4           Brian Stuard   103.0               71.44  2018         278.9
# ...                  ...     ...                 ...   ...           ...
# 2307        Carl Paulson     NaN                 NaN  2012           NaN
# 2308      Peter Tomasulo     NaN                 NaN  2012           NaN
# 2309        Marc Turnesa     NaN                 NaN  2010           NaN
# 2310     Jesper Parnevik     NaN                 NaN  2010           NaN
# 2311  Jim Gallagher, Jr.     NaN                 NaN  2010           NaN
#
#         gir  Average Putts  Average Scrambling  Average Score Points  Wins  \
# ...

# %%
PGA_TechData
# Out:
#              Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 0    Aaron Baddeley           27.0   342.0             0.0
# 1        Aaron Wise           27.0  1498.0             1.0
# 2     Abraham Ancer           29.0   909.0             0.0
# 3       Adam Hadwin           24.0  1054.0             0.0
# 4       Adam Schenk           28.0   239.0             0.0
# ..              ...            ...     ...             ...
# 326             NaN            NaN     NaN             NaN
# 327             NaN            NaN     NaN             NaN
# 328             NaN            NaN     NaN             NaN
# 329             NaN            NaN     NaN             NaN
# 330             NaN            NaN     NaN             NaN
#
#      NUMBER_OF_TOP_Tens  POINTS_BEHIND_LEAD  ROUNDS_PLAYED  \
# 0                   1.0              5275.0           84.0
# 1                   4.0              4119.0           82.0
# 2                   5.0              4708.0           94.0
# ...

# %%
# merge two datasets together, need information include all technical data and numbers that could indicate players' overall performance
PGA_DATA = pd.merge(PGA_TechData, PGA_GenData[['Player Name', 'Year', 'Average Score', 'Wins', 'Top 10', 'Money']], left_on='Player', right_on='Player Name')
# cleanning up duplicated data
del PGA_DATA['Player Name']
del PGA_DATA['POINTS']
del PGA_DATA['NUMBER_OF_WINS']
# cleanning up unneeded data
del PGA_DATA['NUMBER_OF_TOP_Tens']
del PGA_DATA['POINTS_BEHIND_LEAD']
del PGA_DATA['EVENTS_PLAYED']
# show the dataset
PGA_DATA
# Out:
#               Player  ROUNDS_PLAYED  SG_PUTTING_PER_ROUND  TOTAL_SG:PUTTING  \
# 0     Aaron Baddeley           84.0                -0.062            -4.064
# 1     Aaron Baddeley           84.0                -0.062            -4.064
# 2     Aaron Baddeley           84.0                -0.062            -4.064
# 3     Aaron Baddeley           84.0                -0.062            -4.064
# 4     Aaron Baddeley           84.0                -0.062            -4.064
# ...              ...            ...                   ...               ...
# 1024    Zach Johnson           90.0                 0.219            14.042
# 1025    Zach Johnson           90.0                 0.219            14.042
# 1026    Zach Johnson           90.0                 0.219            14.042
# 1027    Zach Johnson           90.0                 0.219            14.042
# 1028     Zecheng Dou           53.0                -0.667           -24.010
#
# ...

# %%
import pandas.plotting._matplotlib as module
# Only looking at data from year 2018 since it is the latest and thus the most relevent data.
temp1 = PGA_DATA[PGA_DATA.Year == 2018]
temp1.plot(x = 'SG_PUTTING_PER_ROUND', y = 'Average Score', kind = 'scatter')

# %%
temp1.plot(x = 'BOGEYS_MADE', y = 'Average Score', kind = 'scatter')

# %%
temp1.plot(x = 'TOTAL_3_PUTTS', y = 'Average Score', kind = 'scatter')

# %%
temp1.plot(x = 'AVG_Driving_DISTANCE', y = 'Average Score', kind = 'scatter')
